# %% [markdown]
# #Introducing the jupyter notebook
#
# * __Integrated visualization and processing__
# * __Storying telling with Data__
#
# https://github.com/ipython/ipython/wiki/A-gallery-of-interesting-IPython-Notebooks

# %% [markdown]
# * One really nice thing about the Jupyter notebook is you can write a number of lines before you execute them, this makes it a great intermediary between a command line interpretor and a script.

# %%
print('line 1')
print('line 2')
# Out:
# line 1
# line 2

# %% [markdown]
# * Another thing is you can use Shell commands:

# %%
# !pwd
# Out:
# /Users/dansandiford/Documents/programming/earthsci_code/python/swc_extras

# %% [markdown]
# * Another thing is you can write notes like this in Markdown format

# %% [markdown]
# ##Cell Types
# * Code (`y`)
# * Markdown (`m`)
# * Raw
# * Heading

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# * You can also display images, video and audio inside the notebook.

# %%
from IPython.display import Image

# %%
Image(url='http://api.brain-map.org/api/v2/section_image_download/102146167?range=0,923,0,987,0,4095&downsample=6')
# Out:
# <img src="http://api.brain-map.org/api/v2/section_image_download/102146167?range=0,923,0,987,0,4095&downsample=6"/>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('kFM2ct0M8TE')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/kFM2ct0M8TE"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ##Plotting

# %%
plt.xkcd()
x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))
plt.title('A simple chirp');

# %% [markdown]
# Matplotlib 1.4 introduces an interactive backend for use in the notebook, called 'nbagg'. You can enable this with %matplotlib notebook.
#
# With this backend, you will get interactive panning and zooming of matplotlib figures in your browser.

# %%
# %matplotlib notebook

# %%
plt.figure()
x = np.linspace(0, 5 * np.pi, 1000)
for n in range(1, 4):
    plt.plot(np.sin(n * x))
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
 
# make sure the value of resolution is a lowercase L,
#  for 'low', not a numeral 1
my_map = Basemap(projection='ortho', lat_0=50, lon_0=-100,
              resolution='l', area_thresh=1000.0)
 
my_map.drawcoastlines()
my_map.drawcountries()
my_map.fillcontinents(color='coral')
my_map.drawmapboundary()
 
my_map.drawmeridians(np.arange(0, 360, 30))
my_map.drawparallels(np.arange(-90, 90, 30))
 
plt.show()

# %% [markdown]
# ##Magics
#
# Within a notebook, you can run different types of code in different cells. With "magics", it is possible to use different languages
#
# By running `% lsmagic` in a cell you get a list of all the available magics.

# %%
# %%HTML
# <marquee>ResBaz Pythoneers!!!</marquee>
# Out:
# <marquee>ResBaz Pythoneers!!!</marquee>

# %%
# %%latex
# $\int_V f(s,t) \,ds\,dt$
# Out:
# $\int_V f(s,t) \,ds\,dt$

# %% [markdown]
# ##Advanced
#
# ###classes and oo programming
# http://nbviewer.ipython.org/github/pylunch/tutorials/blob/master/embray/classes.ipynb
